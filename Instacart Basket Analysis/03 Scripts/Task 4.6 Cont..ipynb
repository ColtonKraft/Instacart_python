# %% [markdown]
# # Contents
# 01 Importing Libaries
# 02 Insuring data consistency of combined dataframe

# %% [markdown]
# # 01 Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Folder location string
path = r'C:\Users\ckra9\Documents\CareerFoundry\Instacart Basket Analysis'

# %% [markdown]
# # Q3 Importing combined dataframe

# %%
# Importing orders_products_combined pkl file
df_comb_ords_prods = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_comb_ords_prods
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    0           0   2539329        1    prior             1
# 2                    0           0   2539329        1    prior             1
# 3                    0           0   2539329        1    prior             1
# 4                    0           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 32434484       3421081     3421081   2977660   206209    prior            13
# 32434485       3421081     3421081   2977660   206209    prior            13
# 32434486       3421081     3421081   2977660   206209    prior            13
# 32434487       3421081     3421081   2977660   206209    prior            13
# 32434488       3421081     3421081   2977660   206209    prior            13
#
# ...

# %% [markdown]
# # 02 Insuring data consistency of combined dataframe

# %%
df_comb_ords_prods.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0      order_id       user_id  order_number  \
# count  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean   1.709858e+06  1.709858e+06  1.710749e+06  1.029372e+05  1.714205e+01
# std    9.864636e+05  9.864636e+05  9.873007e+05  5.946648e+04  1.753504e+01
# min    0.000000e+00  0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556170e+05  8.556170e+05  8.559430e+05  5.142100e+04  5.000000e+00
# 50%    1.709137e+06  1.709137e+06  1.711048e+06  1.026110e+05  1.100000e+01
# 75%    2.565949e+06  2.565949e+06  2.565514e+06  1.543910e+05  2.400000e+01
# max    3.421081e+06  3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#           order_dow  order_hour_of_day  days_since_prior_order    product_id  \
# count  3.243449e+07       3.243449e+07            3.035642e+07  3.243449e+07
# mean   2.738818e+00       1.342498e+01            1.110407e+01  2.557634e+04
# ...

# %%
df_comb_ords_prods.shape
# Out:
# (32434489, 13)

# %% [markdown]
# # Q4
# Shape is a match

# %%
# Dropping unneeded columns df_comb_ords_prods
df_comb_ords_prods = df_comb_ords_prods.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', '_merge'])

# %%
# Importing products data set
df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods_checked
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Dropping unneeded columns df_prods_checked
df_prods_checked = df_prods_checked.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# # Q5
# I merged the two data sets using the .merge function and using the shared column, product_id.

# %%
# Combining the two data sets
df_merged_ords_prods = df_comb_ords_prods.merge(df_prods_checked, on = 'product_id', indicator = True)

# %%
df_merged_ords_prods.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %% [markdown]
# # Q6

# %%
# Merge flag
df_merged_ords_prods['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# Merge looks good to go.

# %%
# Double-checking the shape of new combined dataframe
df_merged_ords_prods.shape
# Out:
# (32404859, 15)

# %%
# Exporting orders_products_merged.pkl
df_merged_ords_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
